# %% [markdown]
# # HW D1

# %% [markdown]
# ### 作業一

# %% [markdown]
# 資料來源: https://www.kaggle.com/ronitf/heart-disease-uci
# 1. 你選這組資料為何重要
# Answer: 對心臟疾病進行預測
# 2. 資料從何而來
# Answer: 從病人身上取得
# 3. 蒐集而來的資料型態為何
# Answer: 結構化資料(CSV形式)，共14個參數，包括性別、年齡等資料
# 4. 這組資料想解決的問題如何評估
# Answer: 藉由數據去預測是否有心血管疾病

# %% [markdown]
# ### 作業二

# %% [markdown]
# 1. 核心問題為何
# Answer: 主要客群、搭車熱門時段以及搭車地點，藉以調派車輛
# 2. 資料從何而來
# Answer: 透過一次又一次的乘客搭車紀錄
# 3. 蒐集而來的資料型態為何
# Answer: 結構化資料，包含參數包括搭車地點、搭車時間、乘客特性等等
# 4. 你要回答的問題，其如何評估
# Answer: 透過模型選出最好的搭車時段及地點等，集中調配車輛，再與先前營收做相比

# %% [markdown]
# ### 作業三
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 197.871
# The Mean absolute error is 11.556
